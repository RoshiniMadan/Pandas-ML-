# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW","toyata","honda"])

# %%
series
# Out:
# 0       BMW
# 1    toyata
# 2     honda
# dtype: object

# %%
#series = 1_dimensional

# %%
colours = pd.Series(["red","blue","white"])

# %%
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
#dataframe = 2_dimensional
car_data = pd.DataFrame({"car make":series,"colours":colours})
car_data
# Out:
#   car make colours
# 0      BMW     red
# 1   toyata    blue
# 2    honda   white

# %%
#import data
car_sales = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
#exporting a dataframe
car_sales.to_csv("exported-car-sales.csv",index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## describe data

# %%
#attribute
car_sales.dtypes

#function
#car_sales.to_csv()
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price            float64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales.mean()
# Out:
# C:\Users\Roshi\AppData\Local\Temp\ipykernel_23028\4073448239.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    131253.237895
# Doors                 4.011579
# Price             16042.814737
# dtype: float64

# %%
car_prices = pd.Series([3000,1500,11250])
car_prices.mean()
# Out:
# 5250.0

# %%
car_sales.sum()
# Out:
# C:\Users\Roshi\AppData\Local\Temp\ipykernel_23028\2394756999.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.sum()
# Odometer (KM)    124690576.0
# Doors                 3811.0
# Price             15240674.0
# dtype: float64

# %%
car_sales["Doors"].sum()
# Out:
# 3811.0

# %%
len(car_sales)
# Out:
# 1000

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## view and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0
# 5   Honda    Red        42652.0    4.0  23883.0
# 6  Toyota   Blue       163453.0    4.0   8473.0

# %%
car_sales.tail(3)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0

# %%
#.loc &.iloc
animals = pd.Series(["cat","dog","bird","panda","snake"],index=[0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#.loc refers to index (location)
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales.loc[3]
# Out:
# Make               Toyota
# Colour              White
# Odometer (KM)    154365.0
# Doors                 4.0
# Price             13434.0
# Name: 3, dtype: object

# %%
#.iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make               Toyota
# Colour              White
# Odometer (KM)    154365.0
# Doors                 4.0
# Price             13434.0
# Name: 3, dtype: object

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0

# %%
car_sales["Make"]
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0      White
# 1       Blue
# 2      White
# 3      White
# 4       Blue
#        ...
# 995    Black
# 996    White
# 997     Blue
# 998    White
# 999     Blue
# Name: Colour, Length: 1000, dtype: object

# %%
car_sales["Make"]
#car_sales.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0       35431.0
# 1      192714.0
# 2       84714.0
# 3      154365.0
# 4      181577.0
#          ...
# 995     35820.0
# 996    155144.0
# 997     66604.0
# 998    215883.0
# 999    248360.0
# Name: Odometer (KM), Length: 1000, dtype: float64

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 3    Toyota  White       154365.0    4.0  13434.0
# 6    Toyota   Blue       163453.0    4.0   8473.0
# 15   Toyota   Blue       205592.0    4.0  16290.0
# 16   Toyota    Red        96742.0    4.0  34465.0
# 20   Toyota    NaN       124844.0    4.0  24130.0
# ..      ...    ...            ...    ...      ...
# 983  Toyota    Red            NaN    4.0  14671.0
# 989  Toyota    Red        41735.0    4.0  13928.0
# 990  Toyota  White       173408.0    4.0   8082.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [379 rows x 5 columns]

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 1       BMW   Blue       192714.0    5.0  19943.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# 6    Toyota   Blue       163453.0    4.0   8473.0
# 8       NaN  White       130538.0    4.0   9374.0
# ..      ...    ...            ...    ...      ...
# 993  Nissan  Black       162523.0    4.0   4696.0
# 994     BMW   Blue       163322.0    3.0  31666.0
# 996     NaN  White       155144.0    3.0   5716.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [597 rows x 5 columns]

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3.0  4.0  5.0
# Make
# BMW      21    0   72
# Honda     0  276    0
# Nissan   38  137    0
# Toyota    0  359    0

# %%
#groupby
car_sales.groupby(["Make"]).mean()
# Out:
# C:\Users\Roshi\AppData\Local\Temp\ipykernel_23028\1678426893.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)     Doors         Price
# Make
# BMW     127491.439560  4.548387  26902.440860
# Honda   125233.374101  4.000000  14618.661922
# Nissan  136809.029070  3.782857  13664.502857
# Toyota  135942.582873  4.000000  15715.257062

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## manipulating data

# %%
car_sales["Make"].str.lower() #access the string value
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996       NaN
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     honda  White        35431.0    4.0  15323.0
# 1       bmw   Blue       192714.0    5.0  19943.0
# 2     honda  White        84714.0    4.0  28343.0
# 3    toyota  White       154365.0    4.0  13434.0
# 4    nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  nissan   Blue        66604.0    4.0  31570.0
# 998   honda  White       215883.0    4.0   4001.0
# 999  toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     honda  White        35431.0    4.0  15323.0
# 1       bmw   Blue       192714.0    5.0  19943.0
# 2     honda  White        84714.0    4.0  28343.0
# 3    toyota  White       154365.0    4.0  13434.0
# 4    nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  nissan   Blue        66604.0    4.0  31570.0
# 998   honda  White       215883.0    4.0   4001.0
# 999  toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
#car_sales_missing["Odometer"].mean()

# %%
#car_sales["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.dropna()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv('car-sales-extended-missing-data.csv')
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
#column from series
seats_column =pd.Series([5,5,5,5,5])

#new column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     honda  White        35431.0    4.0  15323.0    5.0
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0
# 2     honda  White        84714.0    4.0  28343.0    5.0
# 3    toyota  White       154365.0    4.0  13434.0    5.0
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 995  toyota  Black        35820.0    4.0  32042.0    NaN
# 996     NaN  White       155144.0    3.0   5716.0    NaN
# 997  nissan   Blue        66604.0    4.0  31570.0    NaN
# 998   honda  White       215883.0    4.0   4001.0    NaN
# 999  toyota   Blue       248360.0    4.0  12732.0    NaN
#
# [1000 rows x 6 columns]

# %%
car_sales["Seats"].fillna(5,inplace = True)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     honda  White        35431.0    4.0  15323.0    5.0
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0
# 2     honda  White        84714.0    4.0  28343.0    5.0
# 3    toyota  White       154365.0    4.0  13434.0    5.0
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0
# 996     NaN  White       155144.0    3.0   5716.0    5.0
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0
# 998   honda  White       215883.0    4.0   4001.0    5.0
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0
#
# [1000 rows x 6 columns]

# %%
# column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["fuel per 100KM"] = fuel_economy
car_sales
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 3
#       1 # column from python list
#       2 fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
# ----> 3 car_sales["fuel per 100KM"] = fuel_economy
#       4 car_sales
#
# File c:\Users\Roshi\Desktop\sample_project_1\env\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File c:\Users\Roshi\Desktop\sample_project_1\env\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# ...

# %%
car_sales["Total fuel used"] = car-sales["Odometer (KM)"]/100 * car_sales["fuel per 100KM"]
car_sales

# %%
car_sales

# %%
#create a column from a single value
car_sales['number of wheels'] = 4
car_sales

# %%
car_sales["passed road safely"] = True
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 0     honda  White        35431.0    4.0  15323.0    5.0                True
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0                True
# 2     honda  White        84714.0    4.0  28343.0    5.0                True
# 3    toyota  White       154365.0    4.0  13434.0    5.0                True
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0                True
# 996     NaN  White       155144.0    3.0   5716.0    5.0                True
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0                True
# 998   honda  White       215883.0    4.0   4001.0    5.0                True
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0                True
#
# [1000 rows x 7 columns]

# %%
#car_sales = car_sales.drop("total fuel used", axis = 1)
#car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     honda  White        35431.0    4.0  15323.0    5.0
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0
# 2     honda  White        84714.0    4.0  28343.0    5.0
# 3    toyota  White       154365.0    4.0  13434.0    5.0
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0
# 996     NaN  White       155144.0    3.0   5716.0    5.0
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0
# 998   honda  White       215883.0    4.0   4001.0    5.0
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0
#
# [1000 rows x 6 columns]

# %%
car_sales.sample(frac=1)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 441  nissan  Green        90446.0    4.0  13251.0    5.0                True
# 765   honda    Red       108794.0    4.0  15962.0    5.0                True
# 596   honda   Blue        83357.0    4.0  22263.0    5.0                True
# 880   honda   Blue       200219.0    4.0   4606.0    5.0                True
# 112  nissan  White        72122.0    4.0  22943.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 23    honda  Green       130075.0    4.0  21242.0    5.0                True
# 725  toyota    Red       189278.0    NaN   9222.0    5.0                True
# 383   honda  White       144088.0    4.0   5838.0    5.0                True
# 46   toyota  White       100938.0    4.0  25196.0    5.0                True
# 761  nissan   Blue        63686.0    4.0  14432.0    5.0                True
#
# [1000 rows x 7 columns]

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 245   honda   Blue        26616.0    4.0   9521.0    5.0                True
# 498   honda  Green        81764.0    4.0  29004.0    5.0                True
# 130  nissan    NaN        18994.0    4.0   7813.0    5.0                True
# 753     bmw   Blue            NaN    3.0  30020.0    5.0                True
# 434  toyota  White        36463.0    4.0  16805.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 188   honda  White       166028.0    4.0  13056.0    5.0                True
# 649  toyota  Black        86696.0    4.0  30320.0    5.0                True
# 626  nissan  White       235952.0    4.0  13272.0    5.0                True
# 419   honda   Blue       234760.0    4.0  11411.0    5.0                True
# 657  toyota  Black       228063.0    4.0  16308.0    5.0                True
#
# [1000 rows x 7 columns]

# %%
#only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 898  toyota   Blue       237448.0    4.0  16202.0    5.0                True
# 856  toyota    NaN        51788.0    4.0   6480.0    5.0                True
# 46   toyota  White       100938.0    4.0  25196.0    5.0                True
# 538  nissan  White       137477.0    4.0      NaN    5.0                True
# 604  toyota  White        26655.0    4.0  11749.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 774  toyota  Green       201964.0    4.0  13637.0    5.0                True
# 580  nissan    Red            NaN    4.0  13127.0    5.0                True
# 963  toyota  White       107043.0    4.0   7126.0    5.0                True
# 252   honda    NaN            NaN    4.0   7076.0    5.0                True
# 72    honda  White            NaN    4.0   5648.0    5.0                True
#
# [200 rows x 7 columns]

# %%
car_sales_shuffled.sample(frac=0.01)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 807  toyota  Green        88519.0    4.0  18640.0    5.0                True
# 205  toyota   Blue       154576.0    4.0  12553.0    5.0                True
# 876   honda  White       124924.0    4.0  19832.0    5.0                True
# 302   honda   Blue       230570.0    NaN  10676.0    5.0                True
# 394     bmw   Blue        85320.0    3.0  16517.0    5.0                True
# 146     bmw  White       148949.0    3.0  23074.0    5.0                True
# 537   honda   Blue        76579.0    4.0  20511.0    5.0                True
# 483  toyota  White       216076.0    4.0  12152.0    5.0                True
# 887  nissan  White        49310.0    4.0  27146.0    5.0                True
# 97   toyota  Black       133433.0    4.0  16519.0    5.0                True

# %%
car_sales_shuffled.reset_index(drop=True ,inplace=True)
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 0     honda   Blue        26616.0    4.0   9521.0    5.0                True
# 1     honda  Green        81764.0    4.0  29004.0    5.0                True
# 2    nissan    NaN        18994.0    4.0   7813.0    5.0                True
# 3       bmw   Blue            NaN    3.0  30020.0    5.0                True
# 4    toyota  White        36463.0    4.0  16805.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 995   honda  White       166028.0    4.0  13056.0    5.0                True
# 996  toyota  Black        86696.0    4.0  30320.0    5.0                True
# 997  nissan  White       235952.0    4.0  13272.0    5.0                True
# 998   honda   Blue       234760.0    4.0  11411.0    5.0                True
# 999  toyota  Black       228063.0    4.0  16308.0    5.0                True
#
# [1000 rows x 7 columns]

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 0     honda  White        35431.0    4.0  15323.0    5.0                True
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0                True
# 2     honda  White        84714.0    4.0  28343.0    5.0                True
# 3    toyota  White       154365.0    4.0  13434.0    5.0                True
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0                True
# 996     NaN  White       155144.0    3.0   5716.0    5.0                True
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0                True
# 998   honda  White       215883.0    4.0   4001.0    5.0                True
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0                True
#
# [1000 rows x 7 columns]

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  passed road safely
# 0     honda  White      22144.375    4.0  15323.0    5.0                True
# 1       bmw   Blue     120446.250    5.0  19943.0    5.0                True
# 2     honda  White      52946.250    4.0  28343.0    5.0                True
# 3    toyota  White      96478.125    4.0  13434.0    5.0                True
# 4    nissan   Blue     113485.625    3.0  14043.0    5.0                True
# ..      ...    ...            ...    ...      ...    ...                 ...
# 995  toyota  Black      22387.500    4.0  32042.0    5.0                True
# 996     NaN  White      96965.000    3.0   5716.0    5.0                True
# 997  nissan   Blue      41627.500    4.0  31570.0    5.0                True
# 998   honda  White     134926.875    4.0   4001.0    5.0                True
# 999  toyota   Blue     155225.000    4.0  12732.0    5.0                True
#
# [1000 rows x 7 columns]
